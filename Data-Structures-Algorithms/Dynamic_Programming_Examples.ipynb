# %% [markdown]
# ## IMPORT LIBRARIES

# %%
from functools import lru_cache
from typing import List

# %% [markdown]
# ## FIBONACCI WITH MEMORIZATION

# %%
@lru_cache(maxsize=None)
def fib(n: int) -> int:
    if n <= 1:
        return n
    return fib(n - 1) + fib(n - 2)

# %% [markdown]
# ## 0/1 KNAPSACK (classic DP)

# %%
ef knapsack(weights: List[int], values: List[int], capacity: int) -> int:
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]
    for i in range(1, n + 1):
        w, v = weights[i - 1], values[i - 1]
        for c in range(capacity + 1):
            if w > c:
                dp[i][c] = dp[i - 1][c]
            else:
                dp[i][c] = max(dp[i - 1][c], dp[i - 1][c - w] + v)
    return dp[n][capacity]

# %% [markdown]
# ## LONGEST INCREASING SUBSEQUENCE (O(n^2) DP)

# %%
def longest_increasing_subsequence(arr: List[int]) -> int:
    if not arr:
        return 0
    n = len(arr)
    dp = [1] * n
    for i in range(n):
        for j in range(i):
            if arr[j] < arr[i]:
                dp[i] = max(dp[i], dp[j] + 1)
    return max(dp)

# %% [markdown]
# ## PRINT FUNCTION

# %%
if __name__ == "__main__":
    print("fib(10):", fib(10))
    print("Knapsack:", knapsack([2, 3, 4], [4, 5, 6], capacity=5))
    print("LIS:", longest_increasing_subsequence([10, 9, 2, 5, 3, 7, 101, 18]))
